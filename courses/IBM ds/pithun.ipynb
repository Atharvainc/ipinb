# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt
import sklearn as skl

# %%
df=pd.read_csv('.csv')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    ax1 = sns.kdeplot(RedFunction, color="r", label=RedName)
    ax2 = sns.kdeplot(BlueFunction, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')
    plt.show()
    plt.close()

# %%
def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()

# %%
ydata=df['price']
xdata=df.drop('price',axis=1)

# %%
xtrain,xtest,ytrain,ytest=skl.model_selection.train_test_split(xdata,ydata,test_size=0.40,random_state=0)
print(xtest.shape[0])
print(ytest.shape[0])
skl.pipeline.Pipeline
skl.preprocessing.standardScaler,PolynomialFeatures
skl.linear_model.LinearRegression,ridge
skl.metrics.mean_squaared_error,r2_score
skl.model_selection.cross_val_score,train_test_split
# Out:
# 81
# 81

# %%
rx=skl.model_selection.cross_val_score(lr,xdata[['horsepower']],ydata,cv=2)
