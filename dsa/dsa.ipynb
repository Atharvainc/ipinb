# %%
import sys
input=sys.stdin.readline
sys.stdout.write

# %%
def backtrack(left,right,idx)
def main():
    t=int(input())
    candy=[]
    for i in range(2,5000):
        if len(set(str(i)))<=2:
            candy.append(i)
    while t>0:
        n=int(input())
        for c in candy:
            if len(set(str(c*n)))<=2:
                print(c)
                break
        t-=1
if __name__=='__main__':
    main()

# %%
def main():

if __name__=='__main__':
    main()

# %%
nums=[1,2,3,4,5]
nums[-2]
# Out:
# 4

# %%
def maximumProduct(nums: List[int]) -> int:
    nums.sort()
    return max(nums[0]*nums[1]*nums[-1],nums[-1]*nums[-2]*nums[-3])
maximumProduct([-5,0,-9,15])
# Out:
# 675
