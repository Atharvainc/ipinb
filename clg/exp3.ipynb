# %%
s1="hello"
s2 = " world"
s = "helLo WoRld"
print(s1+s2)
# Out:
# hello world

# %%
print(s1[1])
print(s1[1:4])
# Out:
# e
# ell

# %%
print(s.upper())
# Out:
# HELLO WORLD

# %%
print(s.lower())
# Out:
# hello world

# %%
print(s.capitalize())
# Out:
# Hello world

# %%
print(s.title())
# Out:
# Hello World

# %%
s1 = 'abc ghiytgiy'
s2 = "abc dfjnkjsadhgf"
s3 = '''abc JGyhtyGHfdhgsnh
afhbsdkahgbde abc
gjnowrhn'''
print(s1)
print(s2)
print(s3)
# Out:
# abc ghiytgiy
# abc dfjnkjsadhgf
# abc JGyhtyGHfdhgsnh
# afhbsdkahgbde abc
# gjnowrhn

# %%
c1 = s1.upper()
c2 = s2.lower()
c3 = s3.title()
print(c1)
print(c2)
print(c3)
# Out:
# ABC GHIYTGIY
# abc dfjnkjsadhgf
# Abc Jgyhtyghfdhgsnh
# Afhbsdkahgbde Abc
# Gjnowrhn

# %%
c4 = s1.capitalize()
print(c4)
c5 = s2.capitalize()
print(c5)
c6 = s3.capitalize()
print(c6)
# Out:
# Abc ghiytgiy
# Abc dfjnkjsadhgf
# Abc jgyhtyghfdhgsnh
# afhbsdkahgbde abc
# gjnowrhn

# %%
c7 = s2.replace('a', 'b')
print(c7)
c8 = s3.replace ('abc', 'ghi')
print(c8)
print(s1.find('a'))
print(s2.count('g'))
c9 = s1.split()
print(c9)
print(' - '.join(c9))
# Out:
# bbc dfjnkjsbdhgf
# ghi JGyhtyGHfdhgsnh
# afhbsdkahgbde ghi
# gjnowrhn
# 0
# 1
# ['abc', 'ghiytgiy']
# abc - ghiytgiy

# %%
print(s3.startswith("g"))
print(s3.startswith("a"))
print(s3.endswith("g"))
print(s3.endswith("n"))
# Out:
# False
# True
# False
# True
