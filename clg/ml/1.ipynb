# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as abn
import sklearn as skl

# %%
df=pd.read_csv('../../courses/IBM ds/kc_house_data_NaN.csv')

# %%
df.head()
