# %%
print("hello world!")
# Out:
# hello world!

# %%
2+2
# Out:
# 4

# %%
2*2
2/2
2-2
# Out:
# 0

# %%
2/2
# Out:
# 1.0

# %%
2*2
# Out:
# 4

# %%
4**3
# Out:
# 64

# %%
3%2
# Out:
# 1

# %%
x=5

# %%
print(x)
# Out:
# 5

# %%
x=5
print(x)
# Out:
# 5

# %%
y=10
print(y)
# Out:
# 10

# %%
2*x == y
# Out:
# True

# %%
x2 = 10

# %%
_a = 10

# %%
a_ =  10

# %%
Employee@id = 502
# Out:
#   Cell In[16], line 1
#     Employee@id = 502
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
age_Emp = 10; #camel case

# %%
Age_emp=10; #camel case

# %%
a, b, c = 10, 12, 13

# %%
print(a, b, c)
# Out:
# 10 12 13

# %%
a=b=c=75

# %%
print(a, b, c)
# Out:
# 75 75 75

# %%
import keyword
keyword.iskeyword('ussewaaaaaa')
# Out:
# False

# %%
keyword.iskeyword('True')
# Out:
# True

# %%
keyword.iskeyword('true')
# Out:
# False

# %%
a=5
if a==5:
    print(5)
print(10)
# Out:
# 5
# 10

# %%
a =5
print(type(a))
# Out:
# <class 'int'>

# %%
a=7.9
print(type(a))
# Out:
# <class 'float'>

# %%
a="e momo wala mera botuo leke gaya re"
print(type(a))
# Out:
# <class 'str'>

# %%
a=3 + 4i
print(type(a))
# Out:
#   Cell In[31], line 1
#     a=3 + 4i
#           ^
# SyntaxError: invalid decimal literal

# %%
a=3i + 4
print(type(a))
# Out:
#   Cell In[32], line 1
#     a=3i + 4
#       ^
# SyntaxError: invalid decimal literal
