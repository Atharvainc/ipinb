# %%
def greet():
    return "Hello World."

print(greet())
# Out:
# Hello World.

# %%
def add(a,b):
    return a+b;
print(add(2,3))
# Out:
# 5

# %%
fruit = ['apple', 'mango', 'kiwi']
print(fruit)
num = [1, 2, 3, 4, 5]
print(num)
print(num[3])
# Out:
# ['apple', 'mango', 'kiwi']
# [1, 2, 3, 4, 5]
# 4

# %%
num.append(6)
print(num)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def hello():
    print("Hello Python.")
    a = 5
    b = 6
    print(a+b)
    return "Hello World."

print(hello())
# Out:
# Hello Python.
# 11
# Hello World.

# %%
def sub(a,b):
    print("hi")
    print("heyy")
    print("blah blah")
    return a-b
print(sub(5,6))
# Out:
# hi
# heyy
# blah blah
# -1

# %%
abc = ['abc',5,6.7]
print(abc)
# Out:
# ['abc', 5, 6.7]

# %%
abc.extend(['apple','kiwi', 'banana'])
print(abc)
# Out:
# ['abc', 5, 6.7, 'apple', 'kiwi', 'banana']

# %%
abc.insert(2, 'vedika is devika')
print(abc)
# Out:
# ['abc', 5, 'vedika is devika', 6.7, 'apple', 'kiwi', 'banana']

# %%
abc.remove('vedika is devika')
print(abc)
# Out:
# ['abc', 5, 6.7, 'apple', 'kiwi', 'banana']

# %%
abc.insert(5, 5)
print(abc)
# Out:
# ['abc', 5, 6.7, 'apple', 'kiwi', 5, 'banana']

# %%
abc.remove(5)
print(abc)
# Out:
# ['abc', 6.7, 'apple', 'kiwi', 5, 'banana']

# %%
abc.pop(1)
print(abc)
# Out:
# ['abc', 'apple', 'kiwi', 5, 'banana']

# %%
coordinates = (10, 20, 20, 30, 40, 10, 60)
print(coordinates)
# Out:
# (10, 20, 20, 30, 40, 10, 60)

# %%
coordinates.count(20)
# Out:
# 2

# %%
coordinates.index(20)
# Out:
# 1

# %%
len(coordinates)
# Out:
# 7

# %%
max(coordinates)
# Out:
# 60

# %%
min(coordinates)
# Out:
# 10

# %%
color = {'pink', 'white', 'black'}
print(color)
# Out:
# {'black', 'pink', 'white'}

# %%
color = {'pink', 'white', 'black', 'pink'}
print(color)
# Out:
# {'black', 'pink', 'white'}

# %%
color.add('green')
print(color)
# Out:
# {'green', 'black', 'pink', 'white'}

# %%
color.update(['red', 'yellow', 'orange'])
print(color)
# Out:
# {'white', 'green', 'orange', 'pink', 'yellow', 'red', 'black'}

# %%
color.remove('black')
print(color)
# Out:
# {'white', 'green', 'orange', 'pink', 'yellow', 'red'}

# %%
color.discard('purple')
print(color)
# Out:
# {'white', 'green', 'orange', 'pink', 'yellow', 'red'}

# %%
color.clear()
print(color)
# Out:
# set()
